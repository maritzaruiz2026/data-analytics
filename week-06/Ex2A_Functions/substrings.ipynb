# %%
# Exercise 2.A Using built-in functions 
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'Maria Cervantes'

# %%
def parse_and_display(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            last = name[i+1:]
            print(f"Full name: {name}")
            print(f"First name: {first}")
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: Maria Cervantes
# First name: Maria
# Last name: Cervantes

# %%
test_list = ['Martin Rosas', 'Lauryn Koko', 'Ash Burton']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Martin Rosas
# First name: Martin
# Last name: Rosas

# %%
parse_and_display('Maritza Ruiz')
# Out:
# Full name: Maritza Ruiz
# First name: Maritza
# Last name: Ruiz

# %%
def parse_and_display2(name):
    for i in range(len(name)):
        if name[i] == ' ':
            first = name[:i]
            break
    for j in range(len(name)):
        if name[j] == ' ':        
            middle = name[:j]  
    for i in range(len(name)):
        if name[i] == ' ':
            last = name[i:]
            print(f"First name: {first}")
            print(f"Middle name: {middle}")
            print(f"Last name: {last}")
            
test_name = ['Lorde', 'Billie Eilish', 'Megan Thee Stallion']

parse_and_display2(test_name[2])

#Keep getting this output:
#First name: Megan
#Middle name: Megan Thee
#Last name:  Thee Stallion
#First name: Megan
#Middle name: Megan Thee
#Last name:  Stallion
#Unsure why I get two seperate results or why I can't seperate the middle name or the last name in the first result but did seperate the last name in the second result. Will look into later.
# Out:
# First name: Megan
# Middle name: Megan Thee
# Last name:  Thee Stallion
# First name: Megan
# Middle name: Megan Thee
# Last name:  Stallion
