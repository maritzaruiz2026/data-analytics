# %% [markdown]
# # Sales Records Analysis
# ### Author: Maritza Ruiz
# ### Exercise 2.E Using functions for analyzing data
#
# This notebook analyzes a small sales dataset using Python functions. Each function takes the full dataset as its first argument.

# %%
sales_data = [
    ('Laptop', 'East', 1200.00),
    ('Phone', 'West', 850.00),
    ('Tablet', 'East', 400.00),
    ('Monitor', 'South', 650.00),
    ('Keyboard', 'West', 75.00),
    ('Laptop', 'South', 1150.00),
    ('Phone', 'East', 900.00),
    ('Tablet', 'West', 425.00),
    ('Monitor', 'East', 680.00),
    ('Keyboard', 'South', 80.00),
    ('Laptop', 'West', 1300.00),
]

# %% [markdown]
# ## Lab 1. Total sales by region

# %%
def region_total(data, region):
    return sum(amt for _, r, amt in data if r == region)

# %%
print(region_total(sales_data, 'East')) 
print(region_total(sales_data, 'West')) 
print(region_total(sales_data, 'South'))
# Out:
# 3180.0
# 2650.0
# 1880.0

# %% [markdown]
# ## Lab 2. Count of sales by region

# %%
def region_count(data, region):
    return sum(1 for _, r, amt in data if r == region)

# %%
print(region_count(sales_data, 'East')) 
print(region_count(sales_data, 'West')) 
print(region_count(sales_data, 'South'))
# Out:
# 4
# 4
# 3

# %% [markdown]
# ## Lab 3. Average sale amount by region

# %%
def region_average(data, region):
    total = region_total(data, region)
    count = region_count(data, region)
    if count == 0:
        return count
    else:
        region_average = total / count
        return region_average

# %%
print(region_average(sales_data, 'East')) 
print(region_average(sales_data, 'West')) 
print(region_average(sales_data, 'South'))
print(region_average(sales_data, 'North'))
# Out:
# 795.0
# 662.5
# 626.6666666666666
# 0

# %% [markdown]
# ## Lab 4. Filter by sale amount

# %%
def sales_above(data, threshold):
    sale_amount = []
    for record in data:
        if  record[2] > threshold:
            sale_amount.append(record)
  
    return sale_amount

# %%
results = sales_above(sales_data, 500)

for record in results:
    print(record)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Monitor', 'South', 650.0)
# ('Laptop', 'South', 1150.0)
# ('Phone', 'East', 900.0)
# ('Monitor', 'East', 680.0)
# ('Laptop', 'West', 1300.0)

# %% [markdown]
# ## Lab 5. Top and bottom sale

# %%
def top_sale(data):
    return max(data, key=lambda s:s[2])
print(top_sale(sales_data))
def bottom_sale(data):
    return min(data, key=lambda s:s[2])
print(bottom_sale(sales_data))
# Out:
# ('Laptop', 'West', 1300.0)
# ('Keyboard', 'West', 75.0)

# %% [markdown]
# Top sale was Laptop in West region for $1,300.00.
# Bottom sale was Keyboard in West region for $75.00.

# %% [markdown]
# ## Lab 6. Apply a discount

# %%
def apply_discount(data, discount_pct):
       return list(
            map(
                lambda s: (s[0], s[1], s[2] * (1 - discount_pct)),
                data
              )
       )

# %%
for record in sales_data[:3]:
    print(record)

discounted = apply_discount(sales_data, 0.15)
for record in discounted[:3]:
    print(record)
# Out:
# ('Laptop', 'East', 1200.0)
# ('Phone', 'West', 850.0)
# ('Tablet', 'East', 400.0)
# ('Laptop', 'East', 1020.0)
# ('Phone', 'West', 722.5)
# ('Tablet', 'East', 340.0)

# %% [markdown]
# ## Lab 7. Unique regions

# %%
def unique_regions(data):
    return sorted(set(record[1] for record in data))

# %%
print(unique_regions(sales_data))
# Out:
# ['East', 'South', 'West']

# %% [markdown]
# This is similar to DISTINCT in SQL, which could be useful to know of product names being sold and being able to sort them in alphabetical order.

# %% [markdown]
# ## Lab 8. Region summary

# %%
def region_summary(data, region):
    total = region_total(data, region)
    count = region_count(data, region)
    average = region_average(data, region)
    region_data = [record for record in data if record[1] == region]

    print(f'=== {region} Region ===')
    print(f'Records: {count}')
    print(f'Total Sales: ${total:,.2f}') 
    print(f'Average Sale: ${average:,.2f}') 
    top_product, _, top_amount = top_sale(region_data)
    print(f'Top Sale: {top_product} - ${top_amount:,.2f}')


region_summary(sales_data, "West")
# Out:
# === West Region ===
# Records: 4
# Total Sales: $2,650.00
# Average Sale: $662.50
# Top Sale: Laptop - $1,300.00

# %% [markdown]
# ## Lab 9. Full summary

# %%
for region in unique_regions(sales_data):
    summary = region_summary(sales_data, region)
    print(summary)
# Out:
# === East Region ===
# Records: 4
# Total Sales: $3,180.00
# Average Sale: $795.00
# Top Sale: Laptop - $1,200.00
# None
# === South Region ===
# Records: 3
# Total Sales: $1,880.00
# Average Sale: $626.67
# Top Sale: Laptop - $1,150.00
# None
# === West Region ===
# Records: 4
# Total Sales: $2,650.00
# Average Sale: $662.50
# Top Sale: Laptop - $1,300.00
# None

# %% [markdown]
# These set of labs were challenging, to say the least. I did find my self often goin back to my inital scripts to pull from them. Eventhough it was tough at times, it did help me understand the steps better (since it was repetitive). Definitley still learning from trial and error but a win is a win. I am getting more comfortable writing functions.
