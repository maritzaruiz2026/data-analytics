# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %%
import numpy as np
import pandas as pd #Had issues importing pandas, relied on Copilot to assist me in correcting error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
# !{sys.executable} -m ensurepip --default-pip
# Out:
# Looking in links: c:\Users\mruiz\AppData\Local\Temp\tmpwfdudamw
# ...

# %%
# !{sys.executable} -m pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.8 MB 9.1 MB/s eta 0:00:01
#    --------------------- ------------------ 5.2/9.8 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.8 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 11.5 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# ## Series.

# %%
aa = [1,2,3,4] #list
ab = (5,6,7,8) #tuple
ac = {9,10,11,12} #set
ad = {'first': 13,'second': 14,'third': 15,'fourth': 16} #dictionary

# %%
ser1 = pd.Series(aa)
print(ser1)
ser2 = pd.Series(ab)
print(ser2)
###ser3 = pd.Series(ac) #Gives error that says "type is unordered" and this is not an ordered seq
ser3 = pd.Series(list(ac)) #Had to change this to a list in order to complete "DataFrames from Series."
print(ser3)
ser4 = pd.Series(ad)
print(ser4)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    5
# 1    6
# 2    7
# 3    8
# dtype: int64
# 0     9
# 1    10
# 2    11
# 3    12
# dtype: int64
# first     13
# second    14
# third     15
# fourth    16
# dtype: int64

# %%
ser5 = pd.Series(17, 18, 19, 20) #TypeError: Index(...) must be called with a collection of some kind, 18 was passed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 ser5 = pd.Series(17, 18, 19, 20) #TypeError: Index(...) must be called with a collection of some kind, 18 was passed
#
# File c:\Users\mruiz\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:423, in Series.__init__(self, data, index, dtype, name, copy)
#     420 name = ibase.maybe_extract_name(name, data, type(self))
#     422 if index is not None:
# --> 423     index = ensure_index(index)
#     425 if dtype is not None:
#     426     dtype = self._validate_dtype(dtype)
#
# File c:\Users\mruiz\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:7975, in ensure_index(index_like, copy)
#    7973         return Index(index_like, copy=copy, tupleize_cols=False)
#    7974 else:
# -> 7975     return Index(index_like, copy=copy)
#
# ...

# %% [markdown]
# ## DataFrames from Series.

# %%
df1 = pd.DataFrame(ser1)
df1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
#df1.insert(1, "column2", ser2)
#df1.insert(1, "column3", ser3) # I kept getting error NameError: name 'ser3' is not defined
#df1 #no matter what I did it was not running, even when I went up and reran all the ser 

df1.insert(1, "column2", ser2)
df1.insert(2, "column3", ser3)
df1
# Out:
#    0  column2  column3
# 0  1        5        9
# 1  2        6       10
# 2  3        7       11
# 3  4        8       12

# %%
df1.insert(2,'column4', ser4)
df1
# Out:
#    0  column2  column4  column3
# 0  1        5      NaN        9
# 1  2        6      NaN       10
# 2  3        7      NaN       11
# 3  4        8      NaN       12

# %%
df1.loc[4] = [5, 9, 12, 0]
df1
# Out:
#    0  column2  column4  column3
# 0  1        5      NaN        9
# 1  2        6      NaN       10
# 2  3        7      NaN       11
# 3  4        8      NaN       12
# 4  5        9     12.0        0

# %% [markdown]
# ## Reading Data into a DataFrame.

# %% [markdown]
# Create a new variable df2. Use the read_csv function to read the contents of sakila_example.csv into df2. (Note that you will need to save the CSV file to the same folder where Jupyter Notebook is running for this exercise.) Call df2 to review the result.

# %%
df2 = pd.read_csv('sakila_example.csv')
df2
# Out:
#                  title                                        description  \
# 0     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4     ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# ..                 ...                                                ...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#         category language        actor_name
# ...

# %% [markdown]
# Display the top 5 records from df2.

# %%
df2.head(5)
# Out:
#               title                                        description  \
# 0  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 1  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 3  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 4  ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
#
#       category language        actor_name
# 0  Documentary  English  PENELOPE GUINESS
# 1  Documentary  English   CHRISTIAN GABLE
# 2  Documentary  English     LUCILLE TRACY
# 3  Documentary  English       SANDRA PECK
# 4  Documentary  English       JOHNNY CAGE

# %% [markdown]
# Display the last 10 records from df2.

# %%
df2.tail(10)
# Out:
#                  title                                        description  \
# 252       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 253       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 254       ATTACKS HATE  A Fast-Paced Panorama of a Technical Writer An...
# 255  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 256  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 257  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 258  ATTRACTION NEWTON  A Astounding Panorama of a Composer And a Fris...
# 259        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 260        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
# 261        AUTUMN CROW  A Beautiful Tale of a Dentist And a Mad Cow wh...
#
#     category language        actor_name
# 252   Sci-Fi  English      MILLA KEITEL
# 253   Sci-Fi  English     GROUCHO DUNST
# ...

# %% [markdown]
# Show summary information about df2 using the info method.

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        262 non-null    str
#  1   description  262 non-null    str
#  2   category     262 non-null    str
#  3   language     262 non-null    str
#  4   actor_name   262 non-null    str
# dtypes: str(5)
# memory usage: 10.4 KB

# %% [markdown]
# Based on the output I can determine that there are a total of 262 entries and there are five different columns (named title, description, category, language and actor_name). All values in the database have a value (non-null) and the values and dtypes are all str (strings). You can also see the datasets size (10.4kb)

# %% [markdown]
# Show column statistics on df2 using the describe method.

# %%
df2.describe()
# Out:
#                title                                        description  \
# count            262                                                262
# unique            46                                                 46
# top     ARABIA DOGMA  A Touching Epistle of a Madman And a Mad Cow w...
# freq              12                                                 12
#
#        category language    actor_name
# count       262      262           262
# unique       15        1           145
# top      Horror  English  OPRAH KILMER
# freq         55      262             8

# %% [markdown]
# Looking at the describe results, what are the useful insights you can take away? What summarizations are likely not so useful?

# %% [markdown]
# The first line just tell me the total entries per column (count). You can see the unique, top and freq for every column. For example, for title there are 46 unique values, the top title is ARABIA.. and the title is freq 12 times in the database.

# %% [markdown]
# Create a new variable df3. Use the read_csv function to read the contents of northwind_example.csv into df3. (Note again that you will need to save the CSV file to the same folder where Jupyter Notebook is running for this exercise.) Call df3 to review the result.

# %%
df3 = pd.read_csv("northwind_example.csv")
df3
# Out:
#      OrderID                    ProductName  UnitPrice  Quantity
# 0      10248                 Queso Cabrales       14.0        12
# 1      10248  Singaporean Hokkien Fried Mee        9.8        10
# 2      10248         Mozzarella di Giovanni       34.8         5
# 3      10249          Manjimup Dried Apples       42.4        40
# 4      10249                           Tofu       18.6         9
# ..       ...                            ...        ...       ...
# 495    10435         Mozzarella di Giovanni       27.8        10
# 496    10436         Gnocchi di nonna Alice       30.4        40
# 497    10436       Wimmers gute Semmelkndel       26.6        30
# 498    10436             Rhnbru Klosterbier        6.2        24
# 499    10436                      Spegesild        9.6         5
#
# [500 rows x 4 columns]

# %% [markdown]
# Show column statistics on df3 using the describe method.

# %%
df3.describe()
# Out:
#             OrderID   UnitPrice    Quantity
# count    500.000000  500.000000  500.000000
# mean   10341.364000   23.371400   24.330000
# std       54.442663   27.334436   18.069702
# min    10248.000000    2.000000    1.000000
# 25%    10294.000000   10.400000   10.000000
# 50%    10341.000000   15.800000   20.000000
# 75%    10389.000000   27.800000   32.000000
# max    10436.000000  210.800000  120.000000

# %% [markdown]
# Looking at the describe results, what are the useful insights you can take away? How are the summarizations here different than for the previous example, and why?

# %% [markdown]
# Similar to the output for the sakila_example.csv, but since this database has actual values "describe" exxecutes more results. You see the columns mean, std, min, 25%, 50%, 75% and max. The data is divided into three different columns, OrderID, UnitPrice and Quantity. So this is a quick summary of the max/min UnitPrice and such.

# %% [markdown]
# ## Coding a DataFrame.

# %%
test_data = {
    'ID': [1,2,3,4,5,6,7,8],
    'Name': ['Alice', 'Bob', 'Charlie', 'Dominic', 'Eve', 'Frank', 'Grace', 'Heidi'],
    'Age': [25,np.nan,22,19,31,35,np.nan,18],
    'City': ['NY','LA','Chicago','Houston','Phoenix','Boston','Austin','San Diego'],
    'Score': [88, 92, -1, 65, 78, np.nan, 55, 90]}

# %%
df4 = pd.DataFrame(test_data)
df4
# Out:
#    ID     Name   Age       City  Score
# 0   1    Alice  25.0         NY   88.0
# 1   2      Bob   NaN         LA   92.0
# 2   3  Charlie  22.0    Chicago   -1.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 5   6    Frank  35.0     Boston    NaN
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %%
df4.to_csv("test_data.csv", index=False)
